# %% [markdown]
# # Introduccion a la ciencia de datos

# %%
import pandas as pd
ruta_csv = 'https://raw.githubusercontent.com/gitRaulMartinez/pythondatas/main/Padron%20electoral%20-%20Dataset.csv'
df = pd.read_csv(ruta_csv)

# %% [markdown]
# ### Librerias para graficar

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ### Cantidad de votantes macacha guemes

# %%
fig, axes = plt.subplots(2, 2)

axes[0, 0].hist(df.loc[(df['Hora'] == '10:30') & (df['N° del Establecimiento'] == 5175)]['Cantidad de votantes'])
axes[0, 0].set_title('Horario 10:30')
axes[0, 0].set_xlabel('Cantidad de votantes')
axes[0, 0].set_ylabel('Cantidad de mesas')

axes[0, 1].hist(df.loc[(df['Hora'] == '13:00') & (df['N° del Establecimiento'] == 5175)]['Cantidad de votantes'])
axes[0, 1].set_title('Horario 13:00')
axes[0, 1].set_xlabel('Cantidad de votantes')
axes[0, 1].set_ylabel('Cantidad de mesas')


axes[1, 0].hist(df.loc[(df['Hora'] == '15:30') & (df['N° del Establecimiento'] == 5175)]['Cantidad de votantes'])
axes[1, 0].set_title('Horario 15:30')
axes[1, 0].set_xlabel('Cantidad de votantes')
axes[1, 0].set_ylabel('Cantidad de mesas')

axes[1, 1].hist(df.loc[(df['Hora'] == '19:00') & (df['N° del Establecimiento'] == 5175)]['Cantidad de votantes'])
axes[1, 1].set_title('Horario 19:00')
axes[1, 1].set_xlabel('Cantidad de votantes')
axes[1, 1].set_ylabel('Cantidad de mesas')

fig.suptitle('María Magdalena De Macacha Güemes', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Cantidad de votantes en la escuela gral. Pizarro N-4089

# %%
filter_4089 = df.loc[df['N° del Establecimiento'] == 4089]

fig, axes = plt.subplots(2,2)
hora10 = filter_4089.loc[filter_4089['Hora'] == '10:30']
axes[0,0].hist(hora10['Cantidad de votantes'])
axes[0, 0].set_title('Horario 10:30')
axes[0,0].set_xlabel("Cantidad de votantes")
axes[0, 0].set_ylabel('Cantidad de mesas')
hora13 = filter_4089.loc[filter_4089['Hora'] == '13:00']
axes[0,1].hist(hora13['Cantidad de votantes'])
axes[0, 1].set_title('Horario 13:00')
axes[0, 1].set_xlabel("Cantidad de votantes")
axes[0, 1].set_ylabel('Cantidad de mesas')
hora15 = filter_4089.loc[filter_4089['Hora'] == '15:30']
axes[1,0].hist(hora15['Cantidad de votantes'])
axes[1, 0].set_title('Horario 15:30')
axes[1, 0].set_xlabel("Cantidad de votantes")
axes[1, 0].set_ylabel('Cantidad de mesas')
hora19 = filter_4089.loc[filter_4089['Hora'] == '19:00']
axes[1,1].hist(hora19['Cantidad de votantes'])
axes[1, 1].set_title('Horario 19:00')
axes[1, 1].set_xlabel("Cantidad de votantes")
axes[1, 1].set_ylabel('Cantidad de mesas')
fig.suptitle('Escuela Nº 4089-Gral. Pizarro', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

axes[0, 0].hist(df.loc[(df['Hora'] == '10:30') & (df['N° del Establecimiento'] == 5040)]['Cantidad de votantes'])
axes[0, 0].set_title('Horario 10:30')
axes[0, 0].set_xlabel('Cantidad de votantes')
axes[0, 0].set_ylabel('Cantidad de mesas')

axes[0, 1].hist(df.loc[(df['Hora'] == '13:00') & (df['N° del Establecimiento'] == 5040)]['Cantidad de votantes'])
axes[0, 1].set_title('Horario 13:00')
axes[0, 1].set_xlabel('Cantidad de votantes')
axes[0, 1].set_ylabel('Cantidad de mesas')


axes[1, 0].hist(df.loc[(df['Hora'] == '15:30') & (df['N° del Establecimiento'] == 5040)]['Cantidad de votantes'])
axes[1, 0].set_title('Horario 15:30')
axes[1, 0].set_xlabel('Cantidad de votantes')
axes[1, 0].set_ylabel('Cantidad de mesas')

axes[1, 1].hist(df.loc[(df['Hora'] == '19:00') & (df['N° del Establecimiento'] == 5040)]['Cantidad de votantes'])
axes[1, 1].set_title('Horario 19:00')
axes[1, 1].set_xlabel('Cantidad de votantes')
axes[1, 1].set_ylabel('Cantidad de mesas')

fig.suptitle('Colegio Secundario N° 5040', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

axes[0, 0].hist(df.loc[(df['Hora'] == '10:30')]['Cantidad de votantes'])
axes[0, 0].set_title('Horario 10:30')
axes[0, 0].set_xlabel('Cantidad de votantes')
axes[0, 0].set_ylabel('Cantidad de mesas')

axes[0, 1].hist(df.loc[(df['Hora'] == '13:00')]['Cantidad de votantes'])
axes[0, 1].set_title('Horario 13:00')
axes[0, 1].set_xlabel('Cantidad de votantes')
axes[0, 1].set_ylabel('Cantidad de mesas')


axes[1, 0].hist(df.loc[(df['Hora'] == '15:30')]['Cantidad de votantes'])
axes[1, 0].set_title('Horario 15:30')
axes[1, 0].set_xlabel('Cantidad de votantes')
axes[1, 0].set_ylabel('Cantidad de mesas')

axes[1, 1].hist(df.loc[(df['Hora'] == '19:00')]['Cantidad de votantes'])
axes[1, 1].set_title('Horario 19:00')
axes[1, 1].set_xlabel('Cantidad de votantes')
axes[1, 1].set_ylabel('Cantidad de mesas')

fig.suptitle('General', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Escuela Burela

# %%
filter_4275 = df.loc[df['N° del Establecimiento'] == 4275]

fig, axes = plt.subplots(2,2)
hora10 = filter_4275.loc[filter_4275['Hora'] == '10:30']
axes[0,0].hist(hora10['Cantidad de votantes'])
axes[0, 0].set_title('Horario 10:30')
axes[0,0].set_xlabel("Cantidad de votantes")
axes[0, 0].set_ylabel('Cantidad de mesas')

hora13 = filter_4275.loc[filter_4275['Hora'] == '13:00']
axes[0,1].hist(hora13['Cantidad de votantes'])
axes[0, 1].set_title('Horario 13:00')
axes[0, 1].set_xlabel("Cantidad de votantes")
axes[0, 1].set_ylabel('Cantidad de mesas')

hora15 = filter_4275.loc[filter_4275['Hora'] == '15:30']
axes[1,0].hist(hora15['Cantidad de votantes'])
axes[1, 0].set_title('Horario 15:30')
axes[1, 0].set_xlabel("Cantidad de votantes")
axes[1, 0].set_ylabel('Cantidad de mesas')

hora19 = filter_4275.loc[filter_4275['Hora'] == '19:00']
axes[1,1].hist(hora19['Cantidad de votantes'])
axes[1, 1].set_title('Horario 19:00')
axes[1, 1].set_xlabel("Cantidad de votantes")
axes[1, 1].set_ylabel('Cantidad de mesas')

fig.suptitle('Escuela Nº 4275-Osvaldo Burela', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Escuela Lidia Rosa Montellano de Sidorenko

# %%
filter_4586 = df.loc[df['N° del Establecimiento'] == 4586]
fig, axes = plt.subplots(2,2)
hora10 = filter_4586.loc[filter_4586['Hora'] == '10:30']
axes[0,0].hist(hora10['Cantidad de votantes'])
axes[0, 0].set_title('Horario 10:30')
axes[0,0].set_xlabel("Cantidad de votantes")
axes[0, 0].set_ylabel('Cantidad de mesas')

hora13 = filter_4586.loc[filter_4586['Hora'] == '13:00']
axes[0,1].hist(hora13['Cantidad de votantes'])
axes[0, 1].set_title('Horario 13:00')
axes[0, 1].set_xlabel("Cantidad de votantes")
axes[0, 1].set_ylabel('Cantidad de mesas')

hora15 = filter_4586.loc[filter_4586['Hora'] == '15:30']
axes[1,0].hist(hora15['Cantidad de votantes'])
axes[1, 0].set_title('Horario 15:30')
axes[1, 0].set_xlabel("Cantidad de votantes")
axes[1, 0].set_ylabel('Cantidad de mesas')

hora19 = filter_4586.loc[filter_4586['Hora'] == '19:00']
axes[1,1].hist(hora19['Cantidad de votantes'])
axes[1, 1].set_title('Horario 19:00')
axes[1, 1].set_xlabel("Cantidad de votantes")
axes[1, 1].set_ylabel('Cantidad de mesas')

fig.suptitle('Escuela Nº 4586-Lidia Rosa Montellano De Sidorenko', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# #General todas las escuelas

# %%
fig, axes = plt.subplots(2, 2)

axes[0, 0].hist(df.loc[(df['Hora'] == '10:30')]['Cantidad de votantes'])
axes[0, 0].set_title('Horario 10:30')
axes[0, 0].set_xlabel('Cantidad de votantes')
axes[0, 0].set_ylabel('Cantidad de mesas')

axes[0, 1].hist(df.loc[(df['Hora'] == '13:00')]['Cantidad de votantes'])
axes[0, 1].set_title('Horario 13:00')
axes[0, 1].set_xlabel('Cantidad de votantes')
axes[0, 1].set_ylabel('Cantidad de mesas')

axes[1, 0].hist(df.loc[(df['Hora'] == '15:30')]['Cantidad de votantes'])
axes[1, 0].set_title('Horario 15:30')
axes[1, 0].set_xlabel('Cantidad de votantes')
axes[1, 0].set_ylabel('Cantidad de mesas')

axes[1, 1].hist(df.loc[(df['Hora'] == '19:00')]['Cantidad de votantes'])
axes[1, 1].set_title('Horario 19:00')
axes[1, 1].set_xlabel('Cantidad de votantes')
axes[1, 1].set_ylabel('Cantidad de mesas')

fig.suptitle('General', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Analisis multivariado

# %%
sns.set()
data = df.loc[(df['Hora'] == '19:00')]
sns.boxplot(x=data['N° del Establecimiento'], y=data['Cantidad de votantes'])
plt.title('Cantidad de votantes por establecimiento')
plt.show()

# %%
data = df.loc[(df['Hora'] == '19:00')]
total = data['Cantidad de votantes'].sum()
count = data['Cantidad de votantes'].count()

etiquetas = ['Votaron','No votaron']
valores = [total,abs(count * 348 - total)]

# Crear el gráfico de torta utilizando Seaborn
plt.figure(figsize=(6, 6))
sns.set(style='whitegrid')
sns.color_palette("pastel")
plt.pie(valores, labels=etiquetas, autopct='%1.1f%%', startangle=90)

# Configuraciones adicionales
plt.axis('equal')  # Para que el gráfico de torta sea un círculo en lugar de una elipse
plt.title('Participacion general de todo los establecimientos')

# Mostrar el gráfico
plt.show()

# %%
# Datos de ejemplo
establecimientos =  df['N° del Establecimiento'].drop_duplicates().tolist()
valores = []
total = 348
for establecimiento in establecimientos:
  votos = df.loc[(df.iloc[:, 0] == establecimiento) & (df['Hora'] == '19:00')]['Cantidad de votantes'].mean()
  porncentaje = (votos / total) * 100
  valores.append(porncentaje)
# Crear el diagrama de barras utilizando Seaborn
sns.barplot(x=establecimientos, y=valores)

# Configuraciones adicionales
plt.xlabel('N° de establecimiento')
plt.ylim(0, 100)
plt.ylabel('% de Participación')
plt.title('Porcentaje de participación por cada establecimiento')

# Mostrar el diagrama de barras
plt.show()

# %%
etiquetas = ['Votos validos','Votos en blanco','Votos nulos','Sin votar']

data = df.loc[(df['Hora'] == '19:00')]
total = data.groupby('Nombre del Establecimiento')['Cantidad de votantes'].sum()

etiquetas = total.keys().tolist()
valores = total.values.tolist()

# Crear el gráfico de torta utilizando Seaborn
plt.figure(figsize=(6, 6))
sns.set(style='whitegrid')
sns.color_palette('bright')
plt.pie(valores, labels=etiquetas, autopct='%1.1f%%', startangle=90)

# Configuraciones adicionales
plt.axis('equal')  # Para que el gráfico de torta sea un círculo en lugar de una elipse
plt.title('Distribución de votos por establecimientos')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## Analisis de Clustering

# %%
sns.set()
data = df
sns.relplot(x='Cantidad de votantes', y='GOB-Votos afirmativos', hue='Nombre del Establecimiento', data=data)
plt.title('Votos afirmativos para gobernador')
plt.show()

# %%
sns.set()
data = df
sns.relplot(x='Cantidad de votantes', y='GOB-Votos en blanco', hue='Nombre del Establecimiento', data=data)
plt.title('Votos en blanco para gobernador')
plt.show()

# %% [markdown]
# ### Votos afirmativos de todas las escuelas

# %%
data = df
sns.scatterplot(x='Cantidad de votantes', y='GOB-Votos afirmativos', data=data)
sns.scatterplot(x='Cantidad de votantes', y='SEN-Votos afirmativos', color='red', data=data)
sns.scatterplot(x='Cantidad de votantes', y='DIP-Votos afirmativos', color='purple', data=data)
sns.scatterplot(x='Cantidad de votantes', y='INT-Votos afirmativos', color='green', data=data)
sns.scatterplot(x='Cantidad de votantes', y='CNJ-Votos afirmativos', color='orange', data=data)

labels = ['Gobernador', 'Senador', 'Diputados', 'Intendente', 'Concejal']
plt.legend(labels=labels, title='Cargos', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Votos afirmativos")
plt.ylabel('Votos')
plt.show()

# %% [markdown]
# ### Votos en blanco para todas las escuelas

# %%
sns.scatterplot(x=df['Cantidad de votantes'], y=df['GOB-Votos en blanco'], data=df)
sns.scatterplot(x=df['Cantidad de votantes'], y=df['SEN-Votos en blanco'], color='red', data=df)
sns.scatterplot(x=df['Cantidad de votantes'], y=df['DIP-Votos en blanco'], color='purple', data=df)
sns.scatterplot(x=df['Cantidad de votantes'], y=df['INT-Votos en blanco'], color='green', data=df)
sns.scatterplot(x=df['Cantidad de votantes'], y=df['CNJ-Votos en blanco'], color='orange', data=df)

labels = ['Gobernador', 'Senador', 'Diputados', 'Intendente', 'Concejal']
plt.legend(labels=labels, title='Cargos', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Votos en blanco")
#plt.tight_layout()
plt.ylabel("Votos")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

sns.scatterplot(x=df['Cantidad de votantes'], y=df['GOB-Votos en blanco'], data=df, ax=axes[0])
sns.scatterplot(x=df['Cantidad de votantes'], y=df['CNJ-Votos en blanco'], color='red', data=df, ax=axes[1])

axes[0].set_title('GOB-Votos en blanco')
axes[1].set_title('CNJ-Votos en blanco')

plt.tight_layout()
plt.show()

# %%
sns.scatterplot(x=df['Cantidad de votantes'], y=df['GOB-Votos en blanco'], data=df)
sns.scatterplot(x=df['Cantidad de votantes'], y=df['CNJ-Votos en blanco'], color='orange', data=df)

labels = ['Gobernador', 'Concejal']
plt.legend(labels=labels, title='Cargos', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.title("Votos en blanco")
#plt.tight_layout()
plt.ylabel("Votos")
plt.show()

# %% [markdown]
# ## Analisis de correlación

# %%
sns.set()
# matriz de correlación y mapa de calor
columnas_incluidas = df.columns.difference(['N° del Establecimiento', 'Mesa','Total de votantes','Cantidad de votantes','Votos nulos','GOB-Votos en blanco','SEN-Votos en blanco','DIP-Votos en blanco','INT-Votos en blanco','CNJ-Votos en blanco'])

df_renombrado = df[columnas_incluidas].rename(columns={'GOB-Votos afirmativos': 'Gobernador', 'SEN-Votos afirmativos': 'Senador', 'DIP-Votos afirmativos':'Diputados','INT-Votos afirmativos': 'Intendente', 'CNJ-Votos afirmativos':'Concejal'})

correlaciones = df_renombrado.corr()

ax = sns.heatmap(correlaciones, annot=True, fmt='.2f')
plt.title('Votos afirmativos')
plt.show()
# Out:
# <ipython-input-73-4e42f3d38304>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlaciones = df_renombrado.corr()

# %%
sns.set()
# matriz de correlación y mapa de calor
columnas_incluidas = df.columns.difference(['N° del Establecimiento', 'Mesa','Total de votantes','Cantidad de votantes','Votos nulos','GOB-Votos afirmativos','SEN-Votos afirmativos','DIP-Votos afirmativos','INT-Votos afirmativos','CNJ-Votos afirmativos'])

df_renombrado = df[columnas_incluidas].rename(columns={'GOB-Votos en blanco': 'Gobernador', 'SEN-Votos en blanco': 'Senador', 'DIP-Votos en blanco':'Diputados','INT-Votos en blanco': 'Intendente', 'CNJ-Votos en blanco':'Concejal'})

correlaciones = df_renombrado.corr()

ax = sns.heatmap(correlaciones, annot=True, fmt='.2f')
plt.title("Votos en blanco")
plt.show()
# Out:
# <ipython-input-30-459f15b2b37d>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlaciones = df_renombrado.corr()
